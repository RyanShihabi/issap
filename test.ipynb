# %%
import pandas as pd
import numpy as np

from comparison_utils import (compare_filters)
from mining_utils import (grab_facility_mentions,
                          generate_facility_names)
from apriori_utils import (apriori_from_df)

# %%
facility_data = generate_facility_names("./source/all_facilities.csv")

filter = "Completed Task List Activities:"

# %%
facility_data
# Out:
# {'facility_name_abbr': {'Advanced Biological Research System': 'ABRS',
#   'Autonomous Biological System': 'ABS',
#   'Acoustic Diagnostics Facility': 'Acoustic Diagnostics Facility',
#   'Actiwatch': 'Actiwatch',
#   'Actiwatch Spectrum System': 'Actiwatch Spectrum',
#   'Avian Development Facility': 'ADF',
#   'ADvanced Space Experiment Processor': 'ADSEP',
#   'ADvanced Space Experiment Processor-2': 'ADSEP-2',
#   'Animal Enclosure Module': 'AEM',
#   "Anomalous Long Term Effects in Astronauts' Central Nervous System Facility": 'ALTEA Facility',
#   'Additive Manufacturing Facility': 'Manufacturing Device',
#   'Advanced Protein Crystallization Facility': 'APCF',
#   'Aquatic Habitat': 'Aquatic Habitat',
#   'ARCTIC Refrigerator and Freezer': 'ARCTIC',
#   'Advanced Resistive Exercise Device': 'ARED',
#   'Astro Garden': 'Astro Garden',
#   'Astrobee': 'Astrobee',
#   'Bartolomeo': 'Bartolomeo',
#   'Bio-Analyzer': 'Bio-Analyzer',
#   'BioChip SpaceLab': 'BioChip SpaceLab',
#   'Bioculture System': 'Bioculture System Facility',
#   'BioFabrication Facility': 'BioFabrication Facility (BFF)',
#   'Bioimpedance Analyzer': 'Bioimpedance Analyzer',
#   'BIOKON': 'BIOKON',
#   'Biological Experiment Laboratory': 'BioLab',
#   'Bio-Monitor': 'Bio-Monitor',
#   'BioServe Centrifuge': 'BioServe Centrifuge',
#   'BioServe Microscope': 'BioServe Microscope',
#   'Biotube': 'Biotube',
#   'Bone Densitometer': 'Bone Densitometer',
#   'Biological Research In Canisters': 'BRIC',
#   'Biotechnology Specimen Temperature Controller': 'BSTC',
#   'Biotechnology Temperature Refrigerator': 'BTR',
#   'Boiling eXperiment Facility': 'BXF',
#   'Carbon Dioxide Meter': 'Carbon Dioxide Meter',
#   'Clean Bench': 'CB',
#   'Cell Biology Experiment Facility': 'CBEF',
#   'Cell Biology Experiment Facility-L': 'CBEF-L',
#   'Human Research Facility Continuous Blood Pressure Device': 'CBPD',
#   'Chamber for Combustion Experiment': 'CCE',
#   'Cell Culturing': 'CellCult',
#   'Cycle Ergometer with Vibration Isolation and Stabilization (CEVIS) System': 'CEVIS',
#   'Commercial Generic Bioprocessing Apparatus': 'CGBA',
#   'Combustion Integrated Rack - Fluids and Combustion Facility': 'CIR',
#   'Combined Operational Load Bearing External Resistance Treadmill': 'COLBERT',
#   'Cold Atom Lab': 'Cold Atom Lab',
#   'Columbus - External Payload Facility': 'Columbus-EPF',
#   'Confocal Space Microscope': 'Confocal Microscope',
#   'Commercial Refrigerator Incubator Module - Modified': 'CRIM-M',
#   'Cryo Chiller': 'Cryo Chiller',
#   'Cyclops': 'Cyclops',
#   'Dextre Deployable Vision System': 'DDVS',
#   'Device for the Study of Critical Liquids and Crystallization': 'DECLIC',
#   'Double Coldbag': 'Double Coldbag',
#   'European Drawer Rack': 'EDR',
#   'European Drawer Rack-2': 'EDR-2',
#   'New JEM exposed facility platform for payloads of IVA supply experiments': 'EFU Adapter',
#   'IVA Supply Exposed Experiment Platform Type2': 'EFU Adapter2',
#   'Expedite the Processing of Experiments to the Space Station Logistics Carrier': 'ELC',
#   'Electrostatic Levitation Furnace': 'ELF',
#   'ELaboratore Immagini TElevisive - Space 2 Facility': 'ELITE-S2 Facility',
#   'European Modular Cultivation System': 'EMCS',
#   'Electromagnetic Levitator': 'EML',
#   'European Physiology Module': 'EPM',
#   'European Transportation Carrier': 'ETC',
#   'European Technology Exposure Facility': 'EuTEF',
#   'Exposed Experiment Handrail Attachment Mechanism': 'EXHAM Facility',
#   'EXpedite the PRocessing of Experiments&nbsp;to Space Station Rack': 'EXPRESS Rack',
#   'Faraday Research Facility': 'Faraday Research Facility',
#   'Fluids Integrated Rack - Fluids and Combustion Facility': 'FIR',
#   'Fluid Processing Cassette': 'FPC',
#   'Fluid Physics Experiment Facility': 'FPEF',
#   'Freezer/Refrigerator/Incubator Device for Galley and Experimentation': 'FRIDGE',
#   'Freezer-Refrigerator Of STirling cycle': 'FROST',
#   'Fruit Fly Lab': 'Fruit Fly Lab',
#   'Fluid Science Laboratory': 'FSL',
#   'Freezer/Refrigerator/Incubator Device for Galley and Experimentation (FRIDGE)': 'Galley Refrigerator-Freezer',
#   'Gas Analyzer System for Metabolic Analysis Physiology': 'GASMAP',
#   'Group Activation Pack-Fluid Processing Apparatus': 'GAP-FPA',
#   'Granada Crystallization Facility': 'GCF',
#   'General Laboratory Active Cryogenic ISS Experiment Refrigerator': 'GLACIER',
#   'Glovebox Freezer': 'Glovebox Freezer',
#   'Kennedy Space Center Gaseous Nitrogen Freezer': 'GN2',
#   'Gradient Heating Furnace': 'GHF',
#   'Hermes Facility': 'Hermes Facility',
#   'Hand Grip Dynamometer-Pinch Force Dynamometer': 'HGD-PFD',
#   'Human Research Facility Holter Monitor': 'Holter',
#   'Holter Monitor 2': 'Holter Monitor 2',
#   'Hand Posture Analyzer Facility': 'HPA Facility',
#   'Human Research Facility-1': 'HRF-1',
#   'Human Research Facility-2': 'HRF-2',
#   'HTV Small Re-entry Capsule': 'HSRC',
#   'International Commercial Experiment Cubes Facility': 'ICE Cubes Facility',
#   'Iceberg': 'Iceberg',
#   'In Situ Chemiluminescent Reader': 'In Situ Chemiluminescent Reader',
#   'Image Processing Unit': 'IPU',
#   'Image Processing Unit 2': 'IPU2',
#   'Interim Resistive Exercise Device': 'iRED',
#   'ISS SERVIR Environmental Research and Visualization System': 'ISERV (Facility)',
#   'International Space Station Ham Radio (also known as Amateur Radio on the International Space Station (ARISS))': 'ISS Ham Radio (ARISS)',
#   'JAXA Mouse Habitat Unit': 'JAXA Mouse Habitat Unit',
#   'Japanese Experiment Module - Exposed Facility': 'JEM-EF',
#   'JEM Small Satellite Orbital Deployer': 'J-SSOD',
#   'KEyence Research MIcroscope Testbed': 'KERMIT',
#   'Kennedy Space Center Fixation Tube': 'KFT',
#   'KOBAIRO Rack': 'KOBAIRO Rack',
#   'Kubik': 'Kubik',
#   'Light Ions Detector for ALTEA Facility': 'LIDAL Facility',
#   'Life Sciences Glovebox': 'Life Science Glovebox (LSG)',
#   'Light Microscopy Module': 'LMM',
#   'Life Support Rack': 'LSR',
#   'Microgravity Acceleration Measurement System': 'MAMS',
#   'Muscle Atrophy Research and Exercise System': 'MARES',
#   'Mass Measurement Device': 'Mass Measurement Device',
#   'Mice Drawer System Facility': 'MDS Facility',
#   'Minus Eighty-Degree Laboratory Freezer for ISS': 'MELFI',
#   'Microgravity Experiment Research Locker Incubator': 'MERLIN',
#   'MicroPREP': 'MicroPREP',
#   'Mini Coldbag': 'Mini Coldbag',
#   'Made In Space Fiber Optics': 'MIS Fiber',
#   'Materials ISS Experiment Flight Facility': 'MISSE-FF',
#   'Multiple Orbital Bioreactor with Instrumentation and Automated Sampling': 'MOBIAS',
#   'Mobile SpaceLab': 'Mobile SpaceLab',
#   'Mochii': 'Mochii',
#   'MQ-Warmchain': 'MQ-Warmchain',
#   'Microgravity Science Glovebox': 'MSG',
#   'Materials Science Laboratory': 'MSL',
#   'Multi Purpose Small Payload Rack': 'MSPR',
#   'Multi Purpose Small Payload Rack-2': 'MSPR-2',
#   'Materials Science Research Rack-1': 'MSRR-1',
#   'Multiple User System for Earth Sensing Facility': 'MUSES',
#   'Microgravity Vibration Isolation Subsystem': 'MVIS',
#   'Multi-use Variable-g Platform': 'MVP',
#   'Maintenance Work Area': 'MWA',
#   'Nanoracks Bishop Airlock': 'Nanoracks Airlock',
#   'NanoRacks Astrium Centrifuge': 'NanoRacks Astrium Centrifuge',
#   'NanoRacks CubeSat Deployer': 'NanoRacks CubeSat Deployer',
#   'NanoRacks External Platform': 'NanoRacks External Platform',
#   'NanoRacks Kaber Microsat Deployer': 'NanoRacks Microsat Deployer',
#   'NanoRacks Microscopes': 'NanoRacks Microscopes',
#   'Nanoracks Nanode': 'Nanoracks Nanode',
#   'NanoRacks Plate Reader': 'NanoRacks Plate Reader',
#   'NanoRacks Platforms': 'NanoRacks Platforms',
#   'NanoRacks External Cygnus CubeSat Deployer': 'NanoRacks-extCygnus-NRCSD',
#   'NanoRacks-GoPro Fusion': 'NanoRacks-GoPro Fusion',
#   'Portable Clinical Blood Analyzer - i-STAT': 'PCBA',
#   'Protein Crystal Growth - Single Locker Thermal Enclosure System': 'PCG-STES',
#   'Protein Crystallization Research Facility': 'PCRF',
#   'PErsonal Radiation Shielding for intErplanetary missiOns Facility': 'PERSEO Facility',
#   'PFMI Facility': 'PFMI Facility',
#   'Pulmonary Function System': 'PFS',
#   'Portable Glovebox': 'PGB',
#   'Advanced Plant Habitat': 'Plant Habitat',
#   'Polar': 'Polar',
#   'Portable Pulmonary Function System': 'Portable Pulmonary Function System',
#   'Demonstration of a Programmable Isolation Mount to Precisely Control and Manipulate the Acceleration Environment for Microgravity Research': 'Programmable Isolation Mount',
#   'Radiation Area Monitor': 'RAM',
#   'Refrigerated Centrifuge': 'RC',
#   'Rodent Research Facility': 'Rodent Research Facility',
#   'Ryutai Experiment Rack': 'Ryutai',
#   'Space Automated Bioproduct Laboratory': 'SABL',
#   'Saibo Experiment Rack': 'Saibo',
#   'Space Automated Lab Incubator': 'SALI',
#   'Space Acceleration Measurement System-II': 'SAMS-II',
#   'Space Communications and Navigation Testbed': 'SCAN Testbed (Facility)',
#   'Solution Crystallization Observation Facility': 'SCOF',
#   'Space Linear Acceleration Mass Measurement Device': 'SLAMMD',
#   'SlingShot': 'SlingShot',
#   'Solid Fuel Ignition and Extinction': 'SoFIE',
#   'Sun Monitoring on the External Payload Facility of Columbus': 'Solar',
#   'Solidification Using a Baffle in Sealed Ampoules (SUBSA)': 'SUBSA',
#   'SPACE DREAMS Facility': 'SPACE DREAMS Facility',
#   'Spectrum': 'Spectrum',
#   'Synchronized Position Hold Engage Reorient Experimental Satellites': 'SPHERES (Facility)',
#   'Small Payload Support Equipment': 'SPySE',
#   'Space Technology and Advanced Research Systems Inc.-1 Experiment Facility': 'STaARS-1 EF',
#   'TangoLab-1': 'TangoLab-1',
#   'TangoLab-2': 'TangoLab-2',
#   'TELe-Luminescence Analysis System': 'TELLAS',
#   'Tissue Equivalent Proportional Counter': 'TEPC',
#   'Treadmill with Vibration Isolation and Stabilization System': 'TVIS',
#   'Human Research Facility Ultrasound on the International Space Station': 'Ultrasound',
#   'Human Research Facility Ultrasound on the International Space Station 2 ': 'Ultrasound 2',
#   'Urine Monitoring System': 'UMS',
#   'Vegetable Production System': 'Veggie',
#   'Wearable System for Sleep Monitoring in Microgravity Facility': 'Wearable Monitoring Facility',
#   'Wet Lab Kit': 'Wet Lab Kit',
#   'Wet Lab RNA SmartCycler': 'Wet Lab RNA SmartCycler',
#   'Window Observational Research Facility': 'WORF'},
#  'facility_abbr_name': {'ABRS': 'Advanced Biological Research System',
#   'ABS': 'Autonomous Biological System',
#   'Acoustic Diagnostics Facility': 'Acoustic Diagnostics Facility',
#   'Actiwatch': 'Actiwatch',
#   'Actiwatch Spectrum': 'Actiwatch Spectrum System',
#   'ADF': 'Avian Development Facility',
#   'ADSEP': 'ADvanced Space Experiment Processor',
#   'ADSEP-2': 'ADvanced Space Experiment Processor-2',
#   'AEM': 'Animal Enclosure Module',
#   'ALTEA Facility': "Anomalous Long Term Effects in Astronauts' Central Nervous System Facility",
#   'AMF': 'Additive Manufacturing Facility',
#   'APCF': 'Advanced Protein Crystallization Facility',
#   'Aquatic Habitat': 'Aquatic Habitat',
#   'ARCTIC': 'ARCTIC Refrigerator and Freezer',
#   'ARED': 'Advanced Resistive Exercise Device',
#   'Astro Garden': 'Astro Garden',
#   'Astrobee': 'Astrobee',
#   'Bartolomeo': 'Bartolomeo',
#   'Bio-Analyzer': 'Bio-Analyzer',
#   'BioChip SpaceLab': 'BioChip SpaceLab',
#   'Bioculture System Facility': 'Bioculture System',
#   'BioFabrication Facility (BFF)': 'BioFabrication Facility',
#   'Bioimpedance Analyzer': 'Bioimpedance Analyzer',
#   'BIOKON': 'BIOKON',
#   'BioLab': 'Biological Experiment Laboratory',
#   'Bio-Monitor': 'Bio-Monitor',
#   'BioServe Centrifuge': 'BioServe Centrifuge',
#   'BioServe Microscope': 'BioServe Microscope',
#   'Biotube': 'Biotube',
#   'Bone Densitometer': 'Bone Densitometer',
#   'BRIC': 'Biological Research In Canisters',
#   'BSTC': 'Biotechnology Specimen Temperature Controller',
#   'BTR': 'Biotechnology Temperature Refrigerator',
#   'BXF': 'Boiling eXperiment Facility',
#   'Carbon Dioxide Meter': 'Carbon Dioxide Meter',
#   'CB': 'Clean Bench',
#   'CBEF': 'Cell Biology Experiment Facility',
#   'CBEF-L': 'Cell Biology Experiment Facility-L',
#   'CBPD': 'Human Research Facility Continuous Blood Pressure Device',
#   'CCE': 'Chamber for Combustion Experiment',
#   'CellCult': 'Cell Culturing',
#   'CEVIS': 'Cycle Ergometer with Vibration Isolation and Stabilization (CEVIS) System',
#   'CGBA': 'Commercial Generic Bioprocessing Apparatus',
#   'CIR': 'Combustion Integrated Rack - Fluids and Combustion Facility',
#   'COLBERT': 'Combined Operational Load Bearing External Resistance Treadmill',
#   'Cold Atom Lab': 'Cold Atom Lab',
#   'Columbus-EPF': 'Columbus - External Payload Facility',
#   'Confocal Microscope': 'Confocal Space Microscope',
#   'CRIM-M': 'Commercial Refrigerator Incubator Module - Modified',
#   'Cryo Chiller': 'Cryo Chiller',
#   'Cyclops': 'Cyclops',
#   'DDVS': 'Dextre Deployable Vision System',
#   'DECLIC': 'Device for the Study of Critical Liquids and Crystallization',
#   'Double Coldbag': 'Double Coldbag',
#   'EDR': 'European Drawer Rack',
#   'EDR-2': 'European Drawer Rack-2',
#   'EFU Adapter': 'New JEM exposed facility platform for payloads of IVA supply experiments',
#   'EFU Adapter2': 'IVA Supply Exposed Experiment Platform Type2',
#   'ELC': 'Expedite the Processing of Experiments to the Space Station Logistics Carrier',
#   'ELF': 'Electrostatic Levitation Furnace',
#   'ELITE-S2 Facility': 'ELaboratore Immagini TElevisive - Space 2 Facility',
#   'EMCS': 'European Modular Cultivation System',
#   'EML': 'Electromagnetic Levitator',
#   'EPM': 'European Physiology Module',
#   'ETC': 'European Transportation Carrier',
#   'EuTEF': 'European Technology Exposure Facility',
#   'EXHAM Facility': 'Exposed Experiment Handrail Attachment Mechanism',
#   'EXPRESS Rack': 'EXpedite the PRocessing of Experiments&nbsp;to Space Station Rack',
#   'Faraday Research Facility': 'Faraday Research Facility',
#   'FIR': 'Fluids Integrated Rack - Fluids and Combustion Facility',
#   'FPC': 'Fluid Processing Cassette',
#   'FPEF': 'Fluid Physics Experiment Facility',
#   'FRIDGE': 'Freezer/Refrigerator/Incubator Device for Galley and Experimentation',
#   'FROST': 'Freezer-Refrigerator Of STirling cycle',
#   'Fruit Fly Lab': 'Fruit Fly Lab',
#   'FSL': 'Fluid Science Laboratory',
#   'Galley Refrigerator-Freezer': 'Freezer/Refrigerator/Incubator Device for Galley and Experimentation (FRIDGE)',
#   'GASMAP': 'Gas Analyzer System for Metabolic Analysis Physiology',
#   'GAP-FPA': 'Group Activation Pack-Fluid Processing Apparatus',
#   'GCF': 'Granada Crystallization Facility',
#   'GLACIER': 'General Laboratory Active Cryogenic ISS Experiment Refrigerator',
#   'Glovebox Freezer': 'Glovebox Freezer',
#   'GN2': 'Kennedy Space Center Gaseous Nitrogen Freezer',
#   'GHF': 'Gradient Heating Furnace',
#   'Hermes Facility': 'Hermes Facility',
#   'HGD-PFD': 'Hand Grip Dynamometer-Pinch Force Dynamometer',
#   'Holter': 'Human Research Facility Holter Monitor',
#   'Holter Monitor 2': 'Holter Monitor 2',
#   'HPA Facility': 'Hand Posture Analyzer Facility',
#   'HRF-1': 'Human Research Facility-1',
#   'HRF-2': 'Human Research Facility-2',
#   'HSRC': 'HTV Small Re-entry Capsule',
#   'ICE Cubes Facility': 'International Commercial Experiment Cubes Facility',
#   'Iceberg': 'Iceberg',
#   'In Situ Chemiluminescent Reader': 'In Situ Chemiluminescent Reader',
#   'IPU': 'Image Processing Unit',
#   'IPU2': 'Image Processing Unit 2',
#   'iRED': 'Interim Resistive Exercise Device',
#   'ISERV (Facility)': 'ISS SERVIR Environmental Research and Visualization System',
#   'ISS Ham Radio (ARISS)': 'International Space Station Ham Radio (also known as Amateur Radio on the International Space Station (ARISS))',
#   'JAXA Mouse Habitat Unit': 'JAXA Mouse Habitat Unit',
#   'JEM-EF': 'Japanese Experiment Module - Exposed Facility',
#   'J-SSOD': 'JEM Small Satellite Orbital Deployer',
#   'KERMIT': 'KEyence Research MIcroscope Testbed',
#   'KFT': 'Kennedy Space Center Fixation Tube',
#   'KOBAIRO Rack': 'KOBAIRO Rack',
#   'Kubik': 'Kubik',
#   'LIDAL Facility': 'Light Ions Detector for ALTEA Facility',
#   'Life Science Glovebox (LSG)': 'Life Sciences Glovebox',
#   'LMM': 'Light Microscopy Module',
#   'LSR': 'Life Support Rack',
#   'MAMS': 'Microgravity Acceleration Measurement System',
#   'Manufacturing Device': 'Additive Manufacturing Facility',
#   'MARES': 'Muscle Atrophy Research and Exercise System',
#   'Mass Measurement Device': 'Mass Measurement Device',
#   'MDS Facility': 'Mice Drawer System Facility',
#   'MELFI': 'Minus Eighty-Degree Laboratory Freezer for ISS',
#   'MERLIN': 'Microgravity Experiment Research Locker Incubator',
#   'MicroPREP': 'MicroPREP',
#   'Mini Coldbag': 'Mini Coldbag',
#   'MIS Fiber': 'Made In Space Fiber Optics',
#   'MISSE-FF': 'Materials ISS Experiment Flight Facility',
#   'MOBIAS': 'Multiple Orbital Bioreactor with Instrumentation and Automated Sampling',
#   'Mobile SpaceLab': 'Mobile SpaceLab',
#   'Mochii': 'Mochii',
#   'MQ-Warmchain': 'MQ-Warmchain',
#   'MSG': 'Microgravity Science Glovebox',
#   'MSL': 'Materials Science Laboratory',
#   'MSPR': 'Multi Purpose Small Payload Rack',
#   'MSPR-2': 'Multi Purpose Small Payload Rack-2',
#   'MSRR-1': 'Materials Science Research Rack-1',
#   'MUSES': 'Multiple User System for Earth Sensing Facility',
#   'MVIS': 'Microgravity Vibration Isolation Subsystem',
#   'MVP': 'Multi-use Variable-g Platform',
#   'MWA': 'Maintenance Work Area',
#   'Nanoracks Airlock': 'Nanoracks Bishop Airlock',
#   'NanoRacks Astrium Centrifuge': 'NanoRacks Astrium Centrifuge',
#   'NanoRacks CubeSat Deployer': 'NanoRacks CubeSat Deployer',
#   'NanoRacks External Platform': 'NanoRacks External Platform',
#   'NanoRacks Microsat Deployer': 'NanoRacks Kaber Microsat Deployer',
#   'NanoRacks Microscopes': 'NanoRacks Microscopes',
#   'Nanoracks Nanode': 'Nanoracks Nanode',
#   'NanoRacks Plate Reader': 'NanoRacks Plate Reader',
#   'NanoRacks Platforms': 'NanoRacks Platforms',
#   'NanoRacks-extCygnus-NRCSD': 'NanoRacks External Cygnus CubeSat Deployer',
#   'NanoRacks-GoPro Fusion': 'NanoRacks-GoPro Fusion',
#   'PCBA': 'Portable Clinical Blood Analyzer - i-STAT',
#   'PCG-STES': 'Protein Crystal Growth - Single Locker Thermal Enclosure System',
#   'PCRF': 'Protein Crystallization Research Facility',
#   'PERSEO Facility': 'PErsonal Radiation Shielding for intErplanetary missiOns Facility',
#   'PFMI Facility': 'PFMI Facility',
#   'PFS': 'Pulmonary Function System',
#   'PGB': 'Portable Glovebox',
#   'Plant Habitat': 'Advanced Plant Habitat',
#   'Polar': 'Polar',
#   'Portable Pulmonary Function System': 'Portable Pulmonary Function System',
#   'Programmable Isolation Mount': 'Demonstration of a Programmable Isolation Mount to Precisely Control and Manipulate the Acceleration Environment for Microgravity Research',
#   'RAM': 'Radiation Area Monitor',
#   'RC': 'Refrigerated Centrifuge',
#   'Rodent Research Facility': 'Rodent Research Facility',
#   'Ryutai': 'Ryutai Experiment Rack',
#   'SABL': 'Space Automated Bioproduct Laboratory',
#   'Saibo': 'Saibo Experiment Rack',
#   'SALI': 'Space Automated Lab Incubator',
#   'SAMS-II': 'Space Acceleration Measurement System-II',
#   'SCAN Testbed (Facility)': 'Space Communications and Navigation Testbed',
#   'SCOF': 'Solution Crystallization Observation Facility',
#   'SLAMMD': 'Space Linear Acceleration Mass Measurement Device',
#   'SlingShot': 'SlingShot',
#   'SoFIE': 'Solid Fuel Ignition and Extinction',
#   'Solar': 'Sun Monitoring on the External Payload Facility of Columbus',
#   'SUBSA': 'Solidification Using a Baffle in Sealed Ampoules (SUBSA)',
#   'SPACE DREAMS Facility': 'SPACE DREAMS Facility',
#   'Spectrum': 'Spectrum',
#   'SPHERES (Facility)': 'Synchronized Position Hold Engage Reorient Experimental Satellites',
#   'SPySE': 'Small Payload Support Equipment',
#   'STaARS-1 EF': 'Space Technology and Advanced Research Systems Inc.-1 Experiment Facility',
#   'TangoLab-1': 'TangoLab-1',
#   'TangoLab-2': 'TangoLab-2',
#   'TELLAS': 'TELe-Luminescence Analysis System',
#   'TEPC': 'Tissue Equivalent Proportional Counter',
#   'TVIS': 'Treadmill with Vibration Isolation and Stabilization System',
#   'Ultrasound': 'Human Research Facility Ultrasound on the International Space Station',
#   'Ultrasound 2': 'Human Research Facility Ultrasound on the International Space Station 2 ',
#   'UMS': 'Urine Monitoring System',
#   'Veggie': 'Vegetable Production System',
#   'Wearable Monitoring Facility': 'Wearable System for Sleep Monitoring in Microgravity Facility',
#   'Wet Lab Kit': 'Wet Lab Kit',
#   'Wet Lab RNA SmartCycler': 'Wet Lab RNA SmartCycler',
#   'WORF': 'Window Observational Research Facility'},
#  'category_facilities': {'data': {'Biology and Biotechnology': ['ABRS',
#     'ABS',
#     'ADF',
#     'ADSEP',
#     'AEM',
#     'APCF',
#     'Aquatic Habitat',
#     'Astro Garden',
#     'Bio-Analyzer',
#     'BioChip SpaceLab',
#     'Bioculture System Facility',
#     'BioFabrication Facility (BFF)',
#     'BIOKON',
#     'Biotube',
#     'Bone Densitometer',
#     'BRIC',
#     'BSTC',
#     'CBEF',
#     'CBEF-L',
#     'CellCult',
#     'CGBA',
#     'EMCS',
#     'FPC',
#     'Fruit Fly Lab',
#     'GAP-FPA',
#     'GCF',
#     'JAXA Mouse Habitat Unit',
#     'KFT',
#     'MDS Facility',
#     'MERLIN',
#     'MicroPREP',
#     'MOBIAS',
#     'Mobile SpaceLab',
#     'NanoRacks Astrium Centrifuge',
#     'PCRF',
#     'Plant Habitat',
#     'Rodent Research Facility',
#     'SABL',
#     'SALI',
#     'SCOF',
#     'STaARS-1 EF',
#     'Veggie',
#     'Wet Lab RNA SmartCycler'],
#    'Earth and Space Science': ['Columbus-EPF',
#     'ELC',
#     'ISERV (Facility)',
#     'JEM-EF',
#     'Solar',
#     'WORF'],
#    'Educational and Cultural Activities': ['ISS Ham Radio (ARISS)'],
#    'Human Research': ['Acoustic Diagnostics Facility',
#     'Actiwatch',
#     'Actiwatch Spectrum',
#     'ALTEA Facility',
#     'ARED',
#     'Bioimpedance Analyzer',
#     'Bio-Monitor',
#     'CBPD',
#     'CEVIS',
#     'COLBERT',
#     'ELITE-S2 Facility',
#     'EPM',
#     'HGD-PFD',
#     'Holter',
#     'Holter Monitor 2',
#     'HPA Facility',
#     'In Situ Chemiluminescent Reader',
#     'iRED',
#     'LIDAL Facility',
#     'MARES',
#     'PCBA',
#     'PERSEO Facility',
#     'PFS',
#     'Portable Pulmonary Function System',
#     'RAM',
#     'RC',
#     'SLAMMD',
#     'SPACE DREAMS Facility',
#     'TEPC',
#     'TVIS',
#     'Ultrasound',
#     'Ultrasound 2',
#     'UMS',
#     'Wearable Monitoring Facility'],
#    'Manufacture': ['MIS Fiber'],
#    'Multipurpose': ['ADSEP-2',
#     'ARCTIC',
#     'Bartolomeo',
#     'BioLab',
#     'BioServe Centrifuge',
#     'BioServe Microscope',
#     'BTR',
#     'Carbon Dioxide Meter',
#     'CB',
#     'Confocal Microscope',
#     'CRIM-M',
#     'Cryo Chiller',
#     'Cyclops',
#     'Double Coldbag',
#     'EDR',
#     'EDR-2',
#     'EFU Adapter',
#     'ETC',
#     'EXHAM Facility',
#     'EXPRESS Rack',
#     'Faraday Research Facility',
#     'FROST',
#     'Galley Refrigerator-Freezer',
#     'GLACIER',
#     'Glovebox Freezer',
#     'GN2',
#     'Hermes Facility',
#     'HRF-1',
#     'HRF-2',
#     'ICE Cubes Facility',
#     'Iceberg',
#     'IPU',
#     'IPU2',
#     'J-SSOD',
#     'KERMIT',
#     'Kubik',
#     'Life Science Glovebox (LSG)',
#     'LMM',
#     'LSR',
#     'MAMS',
#     'Mass Measurement Device',
#     'MELFI',
#     'Mini Coldbag',
#     'MQ-Warmchain',
#     'MSG',
#     'MSPR',
#     'MSPR-2',
#     'MUSES',
#     'MVIS',
#     'MVP',
#     'MWA',
#     'Nanoracks Airlock',
#     'NanoRacks CubeSat Deployer',
#     'NanoRacks External Platform',
#     'NanoRacks Microsat Deployer',
#     'NanoRacks Microscopes',
#     'Nanoracks Nanode',
#     'NanoRacks Plate Reader',
#     'NanoRacks Platforms',
#     'NanoRacks-extCygnus-NRCSD',
#     'NanoRacks-GoPro Fusion',
#     'PGB',
#     'Polar',
#     'Programmable Isolation Mount',
#     'Ryutai',
#     'Saibo',
#     'SAMS-II',
#     'SlingShot',
#     'Spectrum',
#     'SPySE',
#     'TangoLab-1',
#     'TangoLab-2',
#     'TELLAS',
#     'Wet Lab Kit'],
#    'Physical Science': ['BXF',
#     'CIR',
#     'Cold Atom Lab',
#     'DECLIC',
#     'ELF',
#     'EML',
#     'EuTEF',
#     'FIR',
#     'FPEF',
#     'FSL',
#     'KOBAIRO Rack',
#     'MSL',
#     'MSRR-1',
#     'PCG-STES',
#     'PFMI Facility',
#     'SoFIE',
#     'SUBSA'],
#    'Technology Development and Demonstration': ['Astrobee',
#     'DDVS',
#     'EFU Adapter2',
#     'HSRC',
#     'Manufacturing Device',
#     'MISSE-FF',
#     'Mochii',
#     'SCAN Testbed (Facility)',
#     'SPHERES (Facility)']}},
#  'facility_category': {'ABRS': 'Biology and Biotechnology',
#   'ABS': 'Biology and Biotechnology',
#   'Acoustic Diagnostics Facility': 'Human Research',
#   'Actiwatch': 'Human Research',
#   'Actiwatch Spectrum': 'Human Research',
#   'ADF': 'Biology and Biotechnology',
#   'ADSEP': 'Biology and Biotechnology',
#   'ADSEP-2': 'Multipurpose',
#   'AEM': 'Biology and Biotechnology',
#   'ALTEA Facility': 'Human Research',
#   'APCF': 'Biology and Biotechnology',
#   'Aquatic Habitat': 'Biology and Biotechnology',
#   'ARCTIC': 'Multipurpose',
#   'ARED': 'Human Research',
#   'Astro Garden': 'Biology and Biotechnology',
#   'Astrobee': 'Technology Development and Demonstration',
#   'Bartolomeo': 'Multipurpose',
#   'Bio-Analyzer': 'Biology and Biotechnology',
#   'BioChip SpaceLab': 'Biology and Biotechnology',
#   'Bioculture System Facility': 'Biology and Biotechnology',
#   'BioFabrication Facility (BFF)': 'Biology and Biotechnology',
#   'Bioimpedance Analyzer': 'Human Research',
#   'BIOKON': 'Biology and Biotechnology',
#   'BioLab': 'Multipurpose',
#   'Bio-Monitor': 'Human Research',
#   'BioServe Centrifuge': 'Multipurpose',
#   'BioServe Microscope': 'Multipurpose',
#   'Biotube': 'Biology and Biotechnology',
#   'Bone Densitometer': 'Biology and Biotechnology',
#   'BRIC': 'Biology and Biotechnology',
#   'BSTC': 'Biology and Biotechnology',
#   'BTR': 'Multipurpose',
#   'BXF': 'Physical Science',
#   'Carbon Dioxide Meter': 'Multipurpose',
#   'CB': 'Multipurpose',
#   'CBEF': 'Biology and Biotechnology',
#   'CBEF-L': 'Biology and Biotechnology',
#   'CBPD': 'Human Research',
#   'CellCult': 'Biology and Biotechnology',
#   'CEVIS': 'Human Research',
#   'CGBA': 'Biology and Biotechnology',
#   'CIR': 'Physical Science',
#   'COLBERT': 'Human Research',
#   'Cold Atom Lab': 'Physical Science',
#   'Columbus-EPF': 'Earth and Space Science',
#   'Confocal Microscope': 'Multipurpose',
#   'CRIM-M': 'Multipurpose',
#   'Cryo Chiller': 'Multipurpose',
#   'Cyclops': 'Multipurpose',
#   'DDVS': 'Technology Development and Demonstration',
#   'DECLIC': 'Physical Science',
#   'Double Coldbag': 'Multipurpose',
#   'EDR': 'Multipurpose',
#   'EDR-2': 'Multipurpose',
#   'EFU Adapter': 'Multipurpose',
#   'EFU Adapter2': 'Technology Development and Demonstration',
#   'ELC': 'Earth and Space Science',
#   'ELF': 'Physical Science',
#   'ELITE-S2 Facility': 'Human Research',
#   'EMCS': 'Biology and Biotechnology',
#   'EML': 'Physical Science',
#   'EPM': 'Human Research',
#   'ETC': 'Multipurpose',
#   'EuTEF': 'Physical Science',
#   'EXHAM Facility': 'Multipurpose',
#   'EXPRESS Rack': 'Multipurpose',
#   'Faraday Research Facility': 'Multipurpose',
#   'FIR': 'Physical Science',
#   'FPC': 'Biology and Biotechnology',
#   'FPEF': 'Physical Science',
#   'FROST': 'Multipurpose',
#   'Fruit Fly Lab': 'Biology and Biotechnology',
#   'FSL': 'Physical Science',
#   'Galley Refrigerator-Freezer': 'Multipurpose',
#   'GAP-FPA': 'Biology and Biotechnology',
#   'GCF': 'Biology and Biotechnology',
#   'GLACIER': 'Multipurpose',
#   'Glovebox Freezer': 'Multipurpose',
#   'GN2': 'Multipurpose',
#   'Hermes Facility': 'Multipurpose',
#   'HGD-PFD': 'Human Research',
#   'Holter': 'Human Research',
#   'Holter Monitor 2': 'Human Research',
#   'HPA Facility': 'Human Research',
#   'HRF-1': 'Multipurpose',
#   'HRF-2': 'Multipurpose',
#   'HSRC': 'Technology Development and Demonstration',
#   'ICE Cubes Facility': 'Multipurpose',
#   'Iceberg': 'Multipurpose',
#   'In Situ Chemiluminescent Reader': 'Human Research',
#   'IPU': 'Multipurpose',
#   'IPU2': 'Multipurpose',
#   'iRED': 'Human Research',
#   'ISERV (Facility)': 'Earth and Space Science',
#   'ISS Ham Radio (ARISS)': 'Educational and Cultural Activities',
#   'JAXA Mouse Habitat Unit': 'Biology and Biotechnology',
#   'JEM-EF': 'Earth and Space Science',
#   'J-SSOD': 'Multipurpose',
#   'KERMIT': 'Multipurpose',
#   'KFT': 'Biology and Biotechnology',
#   'KOBAIRO Rack': 'Physical Science',
#   'Kubik': 'Multipurpose',
#   'LIDAL Facility': 'Human Research',
#   'Life Science Glovebox (LSG)': 'Multipurpose',
#   'LMM': 'Multipurpose',
#   'LSR': 'Multipurpose',
#   'MAMS': 'Multipurpose',
#   'Manufacturing Device': 'Technology Development and Demonstration',
#   'MARES': 'Human Research',
#   'Mass Measurement Device': 'Multipurpose',
#   'MDS Facility': 'Biology and Biotechnology',
#   'MELFI': 'Multipurpose',
#   'MERLIN': 'Biology and Biotechnology',
#   'MicroPREP': 'Biology and Biotechnology',
#   'Mini Coldbag': 'Multipurpose',
#   'MIS Fiber': 'Manufacture',
#   'MISSE-FF': 'Technology Development and Demonstration',
#   'MOBIAS': 'Biology and Biotechnology',
#   'Mobile SpaceLab': 'Biology and Biotechnology',
#   'Mochii': 'Technology Development and Demonstration',
#   'MQ-Warmchain': 'Multipurpose',
#   'MSG': 'Multipurpose',
#   'MSL': 'Physical Science',
#   'MSPR': 'Multipurpose',
#   'MSPR-2': 'Multipurpose',
#   'MSRR-1': 'Physical Science',
#   'MUSES': 'Multipurpose',
#   'MVIS': 'Multipurpose',
#   'MVP': 'Multipurpose',
#   'MWA': 'Multipurpose',
#   'Nanoracks Airlock': 'Multipurpose',
#   'NanoRacks Astrium Centrifuge': 'Biology and Biotechnology',
#   'NanoRacks CubeSat Deployer': 'Multipurpose',
#   'NanoRacks External Platform': 'Multipurpose',
#   'NanoRacks Microsat Deployer': 'Multipurpose',
#   'NanoRacks Microscopes': 'Multipurpose',
#   'Nanoracks Nanode': 'Multipurpose',
#   'NanoRacks Plate Reader': 'Multipurpose',
#   'NanoRacks Platforms': 'Multipurpose',
#   'NanoRacks-extCygnus-NRCSD': 'Multipurpose',
#   'NanoRacks-GoPro Fusion': 'Multipurpose',
#   'PCBA': 'Human Research',
#   'PCG-STES': 'Physical Science',
#   'PCRF': 'Biology and Biotechnology',
#   'PERSEO Facility': 'Human Research',
#   'PFMI Facility': 'Physical Science',
#   'PFS': 'Human Research',
#   'PGB': 'Multipurpose',
#   'Plant Habitat': 'Biology and Biotechnology',
#   'Polar': 'Multipurpose',
#   'Portable Pulmonary Function System': 'Human Research',
#   'Programmable Isolation Mount': 'Multipurpose',
#   'RAM': 'Human Research',
#   'RC': 'Human Research',
#   'Rodent Research Facility': 'Biology and Biotechnology',
#   'Ryutai': 'Multipurpose',
#   'SABL': 'Biology and Biotechnology',
#   'Saibo': 'Multipurpose',
#   'SALI': 'Biology and Biotechnology',
#   'SAMS-II': 'Multipurpose',
#   'SCAN Testbed (Facility)': 'Technology Development and Demonstration',
#   'SCOF': 'Biology and Biotechnology',
#   'SLAMMD': 'Human Research',
#   'SlingShot': 'Multipurpose',
#   'SoFIE': 'Physical Science',
#   'Solar': 'Earth and Space Science',
#   'SUBSA': 'Physical Science',
#   'SPACE DREAMS Facility': 'Human Research',
#   'Spectrum': 'Multipurpose',
#   'SPHERES (Facility)': 'Technology Development and Demonstration',
#   'SPySE': 'Multipurpose',
#   'STaARS-1 EF': 'Biology and Biotechnology',
#   'TangoLab-1': 'Multipurpose',
#   'TangoLab-2': 'Multipurpose',
#   'TELLAS': 'Multipurpose',
#   'TEPC': 'Human Research',
#   'TVIS': 'Human Research',
#   'Ultrasound': 'Human Research',
#   'Ultrasound 2': 'Human Research',
#   'UMS': 'Human Research',
#   'Veggie': 'Biology and Biotechnology',
#   'Wearable Monitoring Facility': 'Human Research',
#   'Wet Lab Kit': 'Multipurpose',
#   'Wet Lab RNA SmartCycler': 'Biology and Biotechnology',
#   'WORF': 'Earth and Space Science'},
#  'facility_agency': {'ABRS': 'NASA',
#   'ABS': 'NASA',
#   'Acoustic Diagnostics Facility': 'ESA',
#   'Actiwatch': 'NASA',
#   'Actiwatch Spectrum': 'NASA',
#   'ADF': 'NASA',
#   'ADSEP': 'NASA',
#   'ADSEP-2': 'NASA',
#   'AEM': 'NASA',
#   'ALTEA Facility': 'NASA',
#   'APCF': 'NASA',
#   'Aquatic Habitat': 'JAXA',
#   'ARCTIC': 'NASA',
#   'ARED': 'NASA',
#   'Astro Garden': 'NASA',
#   'Astrobee': 'NASA',
#   'Bartolomeo': 'ESA',
#   'Bio-Analyzer': 'CSA',
#   'BioChip SpaceLab': 'NASA',
#   'Bioculture System Facility': 'NASA',
#   'BioFabrication Facility (BFF)': 'NASA',
#   'Bioimpedance Analyzer': 'ESA',
#   'BIOKON': 'NASA',
#   'BioLab': 'ESA',
#   'Bio-Monitor': 'CSA',
#   'BioServe Centrifuge': 'NASA',
#   'BioServe Microscope': 'NASA',
#   'Biotube': 'NASA',
#   'Bone Densitometer': 'NASA',
#   'BRIC': 'NASA',
#   'BSTC': 'NASA',
#   'BTR': 'NASA',
#   'BXF': 'NASA',
#   'Carbon Dioxide Meter': 'NASA',
#   'CB': 'JAXA',
#   'CBEF': 'JAXA',
#   'CBEF-L': 'JAXA',
#   'CBPD': 'NASA',
#   'CCE': 'JAXA',
#   'CellCult': 'NASA',
#   'CEVIS': 'NASA',
#   'CGBA': 'NASA',
#   'CIR': 'NASA',
#   'COLBERT': 'NASA',
#   'Cold Atom Lab': 'NASA',
#   'Columbus-EPF': 'ESA',
#   'Confocal Microscope': 'JAXA',
#   'CRIM-M': 'NASA',
#   'Cryo Chiller': 'NASA',
#   'Cyclops': 'NASA',
#   'DDVS': 'CSA',
#   'DECLIC': 'NASA',
#   'Double Coldbag': 'NASA',
#   'EDR': 'ESA',
#   'EDR-2': 'ESA',
#   'EFU Adapter': 'JAXA',
#   'EFU Adapter2': 'JAXA',
#   'ELC': 'NASA',
#   'ELF': 'JAXA',
#   'ELITE-S2 Facility': 'NASA',
#   'EMCS': 'ESA',
#   'EML': 'ESA',
#   'EPM': 'ESA',
#   'ETC': 'ESA',
#   'EuTEF': 'ESA',
#   'EXHAM Facility': 'JAXA',
#   'EXPRESS Rack': 'NASA',
#   'Faraday Research Facility': 'NASA',
#   'FIR': 'NASA',
#   'FPC': 'NASA',
#   'FPEF': 'JAXA',
#   'FROST': 'JAXA',
#   'Fruit Fly Lab': 'NASA',
#   'FSL': 'ESA',
#   'Galley Refrigerator-Freezer': 'NASA',
#   'GASMAP': 'NASA',
#   'GAP-FPA': 'NASA',
#   'GCF': 'ESA',
#   'GLACIER': 'NASA',
#   'Glovebox Freezer': 'NASA',
#   'GN2': 'NASA',
#   'GHF': 'JAXA',
#   'Hermes Facility': 'NASA',
#   'HGD-PFD': 'NASA',
#   'Holter': 'NASA',
#   'Holter Monitor 2': 'NASA',
#   'HPA Facility': 'NASA',
#   'HRF-1': 'NASA',
#   'HRF-2': 'NASA',
#   'HSRC': 'JAXA',
#   'ICE Cubes Facility': 'ESA',
#   'Iceberg': 'NASA',
#   'In Situ Chemiluminescent Reader': 'NASA',
#   'IPU': 'JAXA',
#   'IPU2': 'JAXA',
#   'iRED': 'NASA',
#   'ISERV (Facility)': 'NASA',
#   'ISS Ham Radio (ARISS)': 'NASA',
#   'JAXA Mouse Habitat Unit': 'JAXA',
#   'JEM-EF': 'JAXA',
#   'J-SSOD': 'JAXA',
#   'KERMIT': 'NASA',
#   'KFT': 'NASA',
#   'KOBAIRO Rack': 'JAXA',
#   'Kubik': 'ESA',
#   'LIDAL Facility': 'NASA',
#   'Life Science Glovebox (LSG)': 'NASA',
#   'LMM': 'NASA',
#   'LSR': 'ESA',
#   'MAMS': 'NASA',
#   'Manufacturing Device': 'NASA',
#   'MARES': 'ESA',
#   'Mass Measurement Device': 'NASA',
#   'MDS Facility': 'NASA',
#   'MELFI': 'NASA',
#   'MERLIN': 'NASA',
#   'MicroPREP': 'CSA',
#   'Mini Coldbag': 'NASA',
#   'MIS Fiber': 'NASA',
#   'MISSE-FF': 'NASA',
#   'MOBIAS': 'NASA',
#   'Mobile SpaceLab': 'NASA',
#   'Mochii': 'NASA',
#   'MQ-Warmchain': 'NASA',
#   'MSG': 'NASA',
#   'MSL': 'ESA',
#   'MSPR': 'JAXA',
#   'MSPR-2': 'JAXA',
#   'MSRR-1': 'NASA',
#   'MUSES': 'NASA',
#   'MVIS': 'CSA',
#   'MVP': 'NASA',
#   'MWA': 'NASA',
#   'Nanoracks Airlock': 'NASA',
#   'NanoRacks Astrium Centrifuge': 'NASA',
#   'NanoRacks CubeSat Deployer': 'NASA',
#   'NanoRacks External Platform': 'NASA',
#   'NanoRacks Microsat Deployer': 'NASA',
#   'NanoRacks Microscopes': 'NASA',
#   'Nanoracks Nanode': 'NASA',
#   'NanoRacks Plate Reader': 'NASA',
#   'NanoRacks Platforms': 'NASA',
#   'NanoRacks-extCygnus-NRCSD': 'NASA',
#   'NanoRacks-GoPro Fusion': 'NASA',
#   'PCBA': 'NASA',
#   'PCG-STES': 'NASA',
#   'PCRF': 'JAXA',
#   'PERSEO Facility': 'NASA',
#   'PFMI Facility': 'NASA',
#   'PFS': 'NASA',
#   'PGB': 'ESA',
#   'Plant Habitat': 'NASA',
#   'Polar': 'NASA',
#   'Portable Pulmonary Function System': 'ESA',
#   'Programmable Isolation Mount': 'NASA',
#   'RAM': 'NASA',
#   'RC': 'NASA',
#   'Rodent Research Facility': 'NASA',
#   'Ryutai': 'JAXA',
#   'SABL': 'NASA',
#   'Saibo': 'JAXA',
#   'SALI': 'NASA',
#   'SAMS-II': 'NASA',
#   'SCAN Testbed (Facility)': 'NASA',
#   'SCOF': 'JAXA',
#   'SLAMMD': 'NASA',
#   'SlingShot': 'NASA',
#   'SoFIE': 'NASA',
#   'Solar': 'ESA',
#   'SUBSA': 'NASA',
#   'SPACE DREAMS Facility': 'NASA',
#   'Spectrum': 'NASA',
#   'SPHERES (Facility)': 'NASA',
#   'SPySE': 'JAXA',
#   'STaARS-1 EF': 'NASA',
#   'TangoLab-1': 'NASA',
#   'TangoLab-2': 'NASA',
#   'TELLAS': 'JAXA',
#   'TEPC': 'NASA',
#   'TVIS': 'NASA',
#   'Ultrasound': 'NASA',
#   'Ultrasound 2': 'NASA',
#   'UMS': 'NASA',
#   'Veggie': 'NASA',
#   'Wearable Monitoring Facility': 'NASA',
#   'Wet Lab Kit': 'NASA',
#   'Wet Lab RNA SmartCycler': 'NASA',
#   'WORF': 'NASA'},
#  'agency_facilities': {'NASA': ['ABRS',
#    'ABS',
#    'Actiwatch',
#    'Actiwatch Spectrum',
#    'ADF',
#    'ADSEP',
#    'ADSEP-2',
#    'AEM',
#    'ALTEA Facility',
#    'APCF',
#    'ARCTIC',
#    'ARED',
#    'Astro Garden',
#    'Astrobee',
#    'BioChip SpaceLab',
#    'Bioculture System Facility',
#    'BioFabrication Facility (BFF)',
#    'BIOKON',
#    'BioServe Centrifuge',
#    'BioServe Microscope',
#    'Biotube',
#    'Bone Densitometer',
#    'BRIC',
#    'BSTC',
#    'BTR',
#    'BXF',
#    'Carbon Dioxide Meter',
#    'CBPD',
#    'CellCult',
#    'CEVIS',
#    'CGBA',
#    'CIR',
#    'COLBERT',
#    'Cold Atom Lab',
#    'CRIM-M',
#    'Cryo Chiller',
#    'Cyclops',
#    'DECLIC',
#    'Double Coldbag',
#    'ELC',
#    'ELITE-S2 Facility',
#    'EXPRESS Rack',
#    'Faraday Research Facility',
#    'FIR',
#    'FPC',
#    'Fruit Fly Lab',
#    'Galley Refrigerator-Freezer',
#    'GASMAP',
#    'GAP-FPA',
#    'GLACIER',
#    'Glovebox Freezer',
#    'GN2',
#    'Hermes Facility',
#    'HGD-PFD',
#    'Holter',
#    'Holter Monitor 2',
#    'HPA Facility',
#    'HRF-1',
#    'HRF-2',
#    'Iceberg',
#    'In Situ Chemiluminescent Reader',
#    'iRED',
#    'ISERV (Facility)',
#    'ISS Ham Radio (ARISS)',
#    'KERMIT',
#    'KFT',
#    'LIDAL Facility',
#    'Life Science Glovebox (LSG)',
#    'LMM',
#    'MAMS',
#    'Manufacturing Device',
#    'Mass Measurement Device',
#    'MDS Facility',
#    'MELFI',
#    'MERLIN',
#    'Mini Coldbag',
#    'MIS Fiber',
#    'MISSE-FF',
#    'MOBIAS',
#    'Mobile SpaceLab',
#    'Mochii',
#    'MQ-Warmchain',
#    'MSG',
#    'MSRR-1',
#    'MUSES',
#    'MVP',
#    'MWA',
#    'Nanoracks Airlock',
#    'NanoRacks Astrium Centrifuge',
#    'NanoRacks CubeSat Deployer',
#    'NanoRacks External Platform',
#    'NanoRacks Microsat Deployer',
#    'NanoRacks Microscopes',
#    'Nanoracks Nanode',
#    'NanoRacks Plate Reader',
#    'NanoRacks Platforms',
#    'NanoRacks-extCygnus-NRCSD',
#    'NanoRacks-GoPro Fusion',
#    'PCBA',
#    'PCG-STES',
#    'PERSEO Facility',
#    'PFMI Facility',
#    'PFS',
#    'Plant Habitat',
#    'Polar',
#    'Programmable Isolation Mount',
#    'RAM',
#    'RC',
#    'Rodent Research Facility',
#    'SABL',
#    'SALI',
#    'SAMS-II',
#    'SCAN Testbed (Facility)',
#    'SLAMMD',
#    'SlingShot',
#    'SoFIE',
#    'SUBSA',
#    'SPACE DREAMS Facility',
#    'Spectrum',
#    'SPHERES (Facility)',
#    'STaARS-1 EF',
#    'TangoLab-1',
#    'TangoLab-2',
#    'TEPC',
#    'TVIS',
#    'Ultrasound',
#    'Ultrasound 2',
#    'UMS',
#    'Veggie',
#    'Wearable Monitoring Facility',
#    'Wet Lab Kit',
#    'Wet Lab RNA SmartCycler',
#    'WORF'],
#   'ESA': ['Acoustic Diagnostics Facility',
#    'Bartolomeo',
#    'Bioimpedance Analyzer',
#    'BioLab',
#    'Columbus-EPF',
#    'EDR',
#    'EDR-2',
#    'EMCS',
#    'EML',
#    'EPM',
#    'ETC',
#    'EuTEF',
#    'FSL',
#    'GCF',
#    'ICE Cubes Facility',
#    'Kubik',
#    'LSR',
#    'MARES',
#    'MSL',
#    'PGB',
#    'Portable Pulmonary Function System',
#    'Solar'],
#   'JAXA': ['Aquatic Habitat',
#    'CB',
#    'CBEF',
#    'CBEF-L',
#    'CCE',
#    'Confocal Microscope',
#    'EFU Adapter',
#    'EFU Adapter2',
#    'ELF',
#    'EXHAM Facility',
#    'FPEF',
#    'FROST',
#    'GHF',
#    'HSRC',
#    'IPU',
#    'IPU2',
#    'JAXA Mouse Habitat Unit',
#    'JEM-EF',
#    'J-SSOD',
#    'KOBAIRO Rack',
#    'MSPR',
#    'MSPR-2',
#    'PCRF',
#    'Ryutai',
#    'Saibo',
#    'SCOF',
#    'SPySE',
#    'TELLAS'],
#   'CSA': ['Bio-Analyzer', 'Bio-Monitor', 'DDVS', 'MicroPREP', 'MVIS']}}

# %%
facility_mentions = grab_facility_mentions("./reports", facility_data)

df = pd.DataFrame.from_dict(facility_mentions).T
df.index = pd.to_datetime(df.index)
df = df.sort_index(ascending=True)
# Out:
# 100%|██████████| 4026/4026 [00:10<00:00, 379.47it/s]

# %%
facility_mentions_filter = grab_facility_mentions("./reports", facility_data, filter)

df_filter = pd.DataFrame.from_dict(facility_mentions_filter).T
df_filter.index = pd.to_datetime(df_filter.index)
df_filter = df_filter.sort_index(ascending=True)
# Out:
# 100%|██████████| 4026/4026 [00:10<00:00, 397.12it/s]

# %%
df_diff = df - df_filter

# %%
list_mention_dates = {col: [] for col in df_diff.columns}

for col in df_diff:
    print(df_diff[df_diff[col] == 1])
    break
    list_mention_dates[col] = [date.index for date in df_diff[df_diff[col] == 1]]
# Out:
# Empty DataFrame
# Columns: [ABRS, ABS, Acoustic Diagnostics Facility, Actiwatch, Actiwatch Spectrum, ADF, ADSEP, ADSEP-2, AEM, ALTEA Facility, Manufacturing Device, APCF, Aquatic Habitat, ARCTIC, ARED, Astro Garden, Astrobee, Bartolomeo, Bio-Analyzer, BioChip SpaceLab, Bioculture System Facility, BioFabrication Facility (BFF), Bioimpedance Analyzer, BIOKON, BioLab, Bio-Monitor, BioServe Centrifuge, BioServe Microscope, Biotube, Bone Densitometer, BRIC, BSTC, BTR, BXF, Carbon Dioxide Meter, CB, CBEF, CBEF-L, CBPD, CCE, CellCult, CEVIS, CGBA, CIR, COLBERT, Cold Atom Lab, Columbus-EPF, Confocal Microscope, CRIM-M, Cryo Chiller, Cyclops, DDVS, DECLIC, Double Coldbag, EDR, EDR-2, EFU Adapter, EFU Adapter2, ELC, ELF, ELITE-S2 Facility, EMCS, EML, EPM, ETC, EuTEF, EXHAM Facility, EXPRESS Rack, Faraday Research Facility, FIR, FPC, FPEF, FRIDGE, FROST, Fruit Fly Lab, FSL, Galley Refrigerator-Freezer, GASMAP, GAP-FPA, GCF, GLACIER, Glovebox Freezer, GN2, GHF, Hermes Facility, HGD-PFD, Holter, Holter Monitor 2, HPA Facility, HRF-1, HRF-2, HSRC, ICE Cubes Facility, Iceberg, In Situ Chemiluminescent Reader, IPU, IPU2, iRED, ISERV (Facility), ISS Ham Radio (ARISS), ...]
# Index: []
#
# [0 rows x 189 columns]

# %%
list(df_diff[df_diff["MELFI"] == 1]["MELFI"].index)
# Out:
# ['D',
#  'a',
#  't',
#  'e',
#  't',
#  'i',
#  'm',
#  'e',
#  'I',
#  'n',
#  'd',
#  'e',
#  'x',
#  '(',
#  '[',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '8',
#  '-',
#  '2',
#  '3',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '8',
#  '-',
#  '2',
#  '4',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '8',
#  '-',
#  '2',
#  '7',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '8',
#  '-',
#  '2',
#  '9',
#  "'",
#  ',',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '9',
#  '-',
#  '0',
#  '6',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '9',
#  '-',
#  '1',
#  '2',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '9',
#  '-',
#  '1',
#  '9',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '9',
#  '-',
#  '2',
#  '0',
#  "'",
#  ',',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '9',
#  '-',
#  '2',
#  '1',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '1',
#  '8',
#  '-',
#  '0',
#  '9',
#  '-',
#  '2',
#  '4',
#  "'",
#  ',',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '0',
#  '-',
#  '0',
#  '3',
#  '-',
#  '0',
#  '5',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '0',
#  '-',
#  '0',
#  '3',
#  '-',
#  '1',
#  '1',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '0',
#  '-',
#  '0',
#  '3',
#  '-',
#  '1',
#  '7',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '0',
#  '-',
#  '0',
#  '3',
#  '-',
#  '1',
#  '8',
#  "'",
#  ',',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '0',
#  '-',
#  '0',
#  '3',
#  '-',
#  '1',
#  '9',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '0',
#  '-',
#  '0',
#  '4',
#  '-',
#  '2',
#  '7',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '1',
#  '-',
#  '0',
#  '1',
#  '-',
#  '1',
#  '8',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '2',
#  '-',
#  '0',
#  '6',
#  '-',
#  '0',
#  '6',
#  "'",
#  ',',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '3',
#  '-',
#  '0',
#  '5',
#  '-',
#  '1',
#  '8',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '2',
#  '0',
#  '2',
#  '3',
#  '-',
#  '0',
#  '7',
#  '-',
#  '2',
#  '4',
#  "'",
#  ']',
#  ',',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  '=',
#  "'",
#  'd',
#  'a',
#  't',
#  'e',
#  't',
#  'i',
#  'm',
#  'e',
#  '6',
#  '4',
#  '[',
#  'n',
#  's',
#  ']',
#  "'",
#  ',',
#  ' ',
#  'l',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  '=',
#  '1',
#  '8',
#  '8',
#  ',',
#  ' ',
#  'f',
#  'r',
#  'e',
#  'q',
#  '=',
#  'N',
#  'o',
#  'n',
#  'e',
#  ')']

# %%
list_mention_dates
# Out:
# {'ABRS': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'ABS': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'Acoustic Diagnostics Facility': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'Actiwatch': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'Actiwatch Spectrum': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'ADF': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'ADSEP': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'ADSEP-2': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'AEM': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'ALTEA Facility': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'Manufacturing Device': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
# ...
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'Wet Lab Kit': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'Wet Lab RNA SmartCycler': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>],
#  'WORF': [<function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>,
#   <function str.index>]}

# %%
df_diff[df_diff == 1].fillna(0, inplace=True)
list_mentions = df_diff.sum()
df_diff[list_mentions[list_mentions > 0].index].sum().sort_values(ascending=False)
# Out:
# MELFI                         188
# MWA                            91
# ARED                           66
# Ultrasound                     61
# Spectrum                       36
#                              ...
# GLACIER                         1
# ETC                             1
# Bio-Monitor                     1
# Bioculture System Facility      1
# Iceberg                         1
# Length: 65, dtype: int64

# %%
mentions_apriori = apriori_from_df(df)

mentions2_apriori = apriori_from_df(df_filter)
# Out:
#       support                                     itemsets  length
# 81   0.307253                                 (TVIS, ARED)       2
# 56   0.262047                                (ARED, CEVIS)       2
# 138  0.234228                                (TVIS, CEVIS)       2
# 71   0.172876                                (MELFI, ARED)       2
# 130  0.126428                               (MELFI, CEVIS)       2
# ..        ...                                          ...     ...
# 225  0.030303                                   (FSL, MSG)       2
# 191  0.030303                                  (EMCS, MSG)       2
# 132  0.030055                                 (MWA, CEVIS)       2
# 178  0.030055                                 (MELFI, EDR)       2
# 134  0.030055  (Portable Pulmonary Function System, CEVIS)       2
#
# [233 rows x 3 columns]
#       support                                     itemsets  length
# 80   0.307253                                 (TVIS, ARED)       2
# 55   0.257824                                (ARED, CEVIS)       2
# 136  0.234228                                (TVIS, CEVIS)       2
# 70   0.163686                                (MELFI, ARED)       2
# 254  0.121212                                (MELFI, TVIS)       2
# ..        ...                                          ...     ...
# 189  0.030303                                  (EMCS, MSG)       2
# 197  0.030303                      (Holter Monitor 2, EPM)       2
# 222  0.030303                                   (FSL, MSG)       2
# 176  0.030055                                 (MELFI, EDR)       2
# 132  0.030055  (Portable Pulmonary Function System, CEVIS)       2
#
# [230 rows x 3 columns]

# %%
for val in [list(val) for val in mentions_apriori["itemsets"].values]:
    if val not in [list(val) for val in mentions2_apriori["itemsets"].values]:
        print(f"Itemset not found: {val}")
    else:
        original_support = mentions_apriori[mentions_apriori["itemsets"] == frozenset(val)]['support'].values[0]
        filter_support = mentions2_apriori[mentions2_apriori["itemsets"] == frozenset(val)]['support'].values[0]

        print(f"Diff of {val}: {original_support - filter_support}")
# Out:
# Diff of ['TVIS', 'ARED']: 0.0
# Diff of ['ARED', 'CEVIS']: 0.004222553402881302
# Diff of ['TVIS', 'CEVIS']: 0.0
# Diff of ['MELFI', 'ARED']: 0.009190263288623962
# Diff of ['MELFI', 'CEVIS']: 0.00596125186289119
# Diff of ['MELFI', 'TVIS']: 0.0
# Diff of ['CIR', 'ARED']: 0.002732240437158473
# Diff of ['ARED', 'Holter']: 0.0004967709885742577
# Diff of ['ARED', 'Actiwatch']: 0.0
# Diff of ['TVIS', 'Holter']: 0.0
# Diff of ['CIR', 'TVIS']: 0.0
# Diff of ['ARED', 'EPM']: 0.00024838549428712886
# Diff of ['TVIS', 'Actiwatch']: 0.0
# Diff of ['ARED', 'MSG']: 0.002980625931445602
# Diff of ['ARED', 'Ultrasound']: 0.0032290114257327307
# Diff of ['RC', 'MELFI']: 0.0
# Diff of ['TVIS', 'EPM']: 0.0
# Diff of ['ARED', 'CGBA']: 0.0
# Diff of ['Holter', 'CEVIS']: 0.00024838549428712886
# Diff of ['Actiwatch', 'CEVIS']: 0.00024838549428712886
# Diff of ['TVIS', 'CGBA']: 0.0
# Diff of ['CIR', 'CEVIS']: 0.001490312965722801
# Diff of ['MELFI', 'Ultrasound']: 0.01068057625434675
# Diff of ['TVIS', 'Ultrasound']: 0.0
# Diff of ['TVIS', 'MSG']: 0.0
# Diff of ['CEVIS', 'EPM']: 0.00024838549428712886
# Diff of ['ARED', 'CBEF']: 0.0017386984600099437
# Diff of ['ARED', 'HRF-1']: 0.00024838549428712886
# Diff of ['HRF-1', 'Actiwatch']: 0.0
# Diff of ['Holter', 'EPM']: 0.0
# Diff of ['Ultrasound', 'CEVIS']: 0.0017386984600099298
# Diff of ['TVIS', 'HRF-1']: 0.0
# Diff of ['MELFI', 'MSG']: 0.006209637357178346
# Diff of ['EXPRESS Rack', 'ARED']: 0.0009935419771485293
# Diff of ['CGBA', 'CEVIS']: 0.0
# Diff of ['MSG', 'CEVIS']: 0.0007451564828614005
# Diff of ['MELFI', 'CBEF']: 0.00695479384003974
# Diff of ['MELFI', 'Holter']: 0.001241927471435672
# Diff of ['RC', 'ARED']: 0.0
# Diff of ['TVIS', 'CBEF']: 0.0
# Diff of ['CIR', 'MELFI']: 0.004470938897168403
# Diff of ['CIR', 'EPM']: 0.0007451564828614005
# Diff of ['ARED', 'EDR']: 0.0002483854942871358
# Diff of ['Solar', 'ARED']: 0.0012419274714356651
# Diff of ['Holter', 'Actiwatch']: 0.0
# Diff of ['Mass Measurement Device', 'SLAMMD']: 0.0
# Diff of ['HRF-1', 'CEVIS']: 0.0
# Diff of ['TVIS', 'EXPRESS Rack']: 0.0
# Diff of ['PFS', 'CEVIS']: 0.005216095380029803
# Diff of ['CIR', 'CGBA']: 0.0
# Diff of ['CIR', 'CBEF']: 0.0009935419771485363
# Diff of ['MWA', 'MELFI']: 0.01862891207153502
# Diff of ['CGBA', 'EPM']: 0.0
# Diff of ['Ultrasound 2', 'Ultrasound']: 0.00844510680576254
# Diff of ['EMCS', 'ARED']: 0.0
# Diff of ['TVIS', 'EDR']: 0.0
# Diff of ['EXPRESS Rack', 'CEVIS']: 0.0007451564828614005
# Diff of ['CIR', 'Holter']: 0.0004967709885742716
# Diff of ['ARED', 'Mass Measurement Device']: 0.0007451564828614005
# Diff of ['MELFI', 'Actiwatch']: 0.0009935419771485363
# Diff of ['ARED', 'SLAMMD']: 0.0
# Diff of ['FPEF', 'ARED']: 0.0
# Diff of ['EPM', 'EDR']: 0.0
# Diff of ['CBEF', 'CEVIS']: 0.0007451564828614005
# Diff of ['RC', 'TVIS']: 0.0
# Diff of ['CGBA', 'EDR']: 0.0
# Diff of ['TVIS', 'EMCS']: 0.0
# Diff of ['CIR', 'EDR']: 0.0
# Diff of ['CBEF', 'CB']: 0.0
# Diff of ['CBEF', 'EPM']: 0.0
# Diff of ['EMCS', 'CGBA']: 0.0
# Diff of ['MELFI', 'EPM']: 0.0009935419771485293
# Diff of ['TVIS', 'Solar']: 0.0
# Diff of ['RC', 'CEVIS']: 0.0
# Diff of ['CGBA', 'CBEF']: 0.0
# Diff of ['TVIS', 'SLAMMD']: 0.0
# Diff of ['FSL', 'ARED']: 0.0004967709885742647
# Diff of ['EMCS', 'EPM']: 0.0
# Diff of ['FPEF', 'TVIS']: 0.0
# Diff of ['TVIS', 'Mass Measurement Device']: 0.0
# Diff of ['PFS', 'ARED']: 0.0017386984600099367
# Diff of ['CIR', 'EMCS']: 0.0
# Diff of ['EMCS', 'EDR']: 0.0
# Diff of ['Holter', 'Ultrasound']: 0.002980625931445602
# Diff of ['Holter', 'CGBA']: 0.0
# Diff of ['EMCS', 'CBEF']: 0.0
# Diff of ['CIR', 'Solar']: 0.001490312965722801
# Diff of ['ARED', 'CB']: 0.0002483854942871358
# Diff of ['Holter', 'CBEF']: 0.0014903129657228079
# Diff of ['CBEF', 'EDR']: 0.0
# Diff of ['CIR', 'MSG']: 0.0007451564828614005
# Diff of ['Actiwatch', 'EPM']: 0.0
# Diff of ['CIR', 'CB']: 0.0
# Diff of ['MELFI', 'EXPRESS Rack']: 0.0032290114257327376
# Diff of ['TVIS', 'FSL']: 0.0
# Diff of ['ARED', 'LMM']: 0.001490312965722801
# Diff of ['EPM', 'CB']: 0.0
# Diff of ['Solar', 'EPM']: 0.0
# Diff of ['FPEF', 'EPM']: 0.0
# Diff of ['CGBA', 'CB']: 0.0
# Diff of ['EDR', 'CB']: 0.0002483854942871358
# Diff of ['Holter', 'Holter Monitor 2']: 0.0
# Diff of ['TVIS', 'CB']: 0.0
# Diff of ['CEVIS', 'EDR']: 0.0
# Diff of ['Solar', 'CGBA']: 0.0
# Diff of ['CIR', 'Ultrasound']: 0.0017386984600099367
# Diff of ['FPEF', 'Holter']: 0.00024838549428712886
# Diff of ['EMCS', 'CB']: 0.0
# Diff of ['Solar', 'CEVIS']: 0.0014903129657228079
# Diff of ['MWA', 'ARED']: 0.00521609538002981
# Diff of ['ARED', 'Holter Monitor 2']: 0.0
# Diff of ['Solar', 'CBEF']: 0.0007451564828614005
# Diff of ['Solar', 'EDR']: 0.00024838549428712886
# Diff of ['CIR', 'FPEF']: 0.00024838549428712886
# Diff of ['FSL', 'CGBA']: 0.0
# Diff of ['FSL', 'EPM']: 0.0002483854942871358
# Diff of ['CIR', 'FSL']: 0.0
# Diff of ['MELFI', 'CGBA']: 0.0
# Diff of ['Holter', 'MSG']: 0.00024838549428712886
# Diff of ['Solar', 'FSL']: 0.0007451564828614005
# Diff of ['CEVIS', 'SLAMMD']: 0.0
# Diff of ['FPEF', 'FSL']: 0.0
# Diff of ['EMCS', 'Solar']: 0.0002483854942871358
# Diff of ['FPEF', 'CGBA']: 0.0
# Diff of ['Mass Measurement Device', 'CEVIS']: 0.0002483854942871358
# Diff of ['EMCS', 'Holter']: 0.0
# Diff of ['Solar', 'Holter']: 0.0004967709885742647
# Diff of ['FSL', 'EDR']: 0.0
# Diff of ['FPEF', 'EMCS']: 0.0
# Diff of ['PCRF', 'FPEF']: 0.0
# Diff of ['Holter', 'EDR']: 0.0
# Diff of ['TVIS', 'Holter Monitor 2']: 0.0
# Diff of ['PCRF', 'ARED']: 0.0
# Diff of ['Ultrasound', 'EPM']: 0.001241927471435672
# Diff of ['TVIS', 'PFS']: 0.0
# Diff of ['WORF', 'ARED']: 0.0004967709885742647
# Diff of ['FPEF', 'Solar']: 0.0
# Diff of ['FSL', 'Holter']: 0.0
# Diff of ['FPEF', 'EDR']: 0.0
# Diff of ['PCRF', 'CGBA']: 0.0
# Diff of ['PCRF', 'EMCS']: 0.0
# Diff of ['PCRF', 'Solar']: 0.0002483854942871358
# Diff of ['PFS', 'Portable Pulmonary Function System']: 0.0
# Diff of ['EMCS', 'FSL']: 0.0
# Diff of ['MSG', 'CGBA']: 0.0
# Diff of ['PCRF', 'FSL']: 0.0
# Diff of ['MSG', 'EPM']: 0.0
# Diff of ['FPEF', 'CEVIS']: 0.0
# Diff of ['Holter', 'SLAMMD']: 0.0
# Diff of ['PCRF', 'EDR']: 0.0
# Diff of ['EMCS', 'CEVIS']: 0.0
# Diff of ['PCRF', 'EPM']: 0.0
# Diff of ['Holter', 'Mass Measurement Device']: 0.0
# Diff of ['MELFI', 'PFS']: 0.002732240437158473
# Diff of ['MSL', 'ARED']: 0.0007451564828614005
# Diff of ['MSG', 'CBEF']: 0.0009935419771485363
# Diff of ['CIR', 'PCRF']: 0.0
# Diff of ['MELFI', 'Solar']: 0.006458022851465472
# Diff of ['CIR', 'Actiwatch']: 0.0004967709885742716
# Diff of ['PCRF', 'CBEF']: 0.0
# Diff of ['FPEF', 'CBEF']: 0.0004967709885742647
# Diff of ['EPM', 'SLAMMD']: 0.0
# Diff of ['PCRF', 'Holter']: 0.0
# Diff of ['CIR', 'LMM']: 0.00024838549428712886
# Diff of ['FSL', 'CBEF']: 0.0002483854942871358
# Diff of ['Mass Measurement Device', 'EPM']: 0.0
# Diff of ['CIR', 'SLAMMD']: 0.0
# Diff of ['PCRF', 'TVIS']: 0.0
# Diff of ['Holter', 'CB']: 0.0002483854942871358
# Diff of ['CGBA', 'SLAMMD']: 0.0
# Diff of ['TVIS', 'LMM']: 0.0
# Diff of ['FSL', 'CEVIS']: 0.00024838549428712886
# Diff of ['Holter Monitor 2', 'CEVIS']: 0.0
# Diff of ['CIR', 'Mass Measurement Device']: 0.0
# Diff of ['CBEF', 'Ultrasound']: 0.0034773969200198665
# Diff of ['CGBA', 'Mass Measurement Device']: 0.0
# Diff of ['FIR', 'LMM']: 0.0
# Diff of ['MELFI', 'Mass Measurement Device']: 0.0029806259314456088
# Diff of ['Solar', 'MSG']: 0.0009935419771485363
# Diff of ['CGBA', 'Actiwatch']: 0.0
# Diff of ['MSG', 'Actiwatch']: 0.00024838549428712886
# Diff of ['Solar', 'CB']: 0.00024838549428712886
# Diff of ['CEVIS', 'CB']: 0.0002483854942871358
# Diff of ['Solar', 'SLAMMD']: 0.0
# Diff of ['Holter', 'LMM']: 0.0
# Diff of ['LMM', 'EPM']: 0.0007451564828614005
# Diff of ['FPEF', 'SLAMMD']: 0.0
# Diff of ['FIR', 'ARED']: 0.0017386984600099298
# Diff of ['EDR', 'SLAMMD']: 0.0
# Diff of ['MELFI', 'EMCS']: 0.0
# Diff of ['LMM', 'CBEF']: 0.0004967709885742716
# Diff of ['FPEF', 'SCOF']: 0.0
# Diff of ['FPEF', 'CB']: 0.0
# Diff of ['FSL', 'CB']: 0.0
# Diff of ['ARED', 'SCOF']: 0.0002483854942871358
# Itemset not found: ['MELFI', 'LMM']
# Diff of ['PCRF', 'CB']: 0.0
# Diff of ['Solar', 'Mass Measurement Device']: 0.0
# Diff of ['CIR', 'MSL']: 0.0002483854942871358
# Diff of ['FPEF', 'Mass Measurement Device']: 0.0
# Diff of ['MSL', 'Holter']: 0.0
# Diff of ['MSL', 'CBEF']: 0.0
# Diff of ['MELFI', 'SLAMMD']: 0.0004967709885742647
# Diff of ['RC', 'Ultrasound']: 0.0
# Diff of ['FSL', 'SLAMMD']: 0.00024838549428712886
# Diff of ['Mass Measurement Device', 'EDR']: 0.0
# Diff of ['EMCS', 'SLAMMD']: 0.0
# Diff of ['Mass Measurement Device', 'CBEF']: 0.0004967709885742647
# Diff of ['CBEF', 'SLAMMD']: 0.0
# Diff of ['MELFI', 'HRF-1']: 0.0009935419771485328
# Diff of ['LMM', 'CGBA']: 0.0
# Diff of ['TVIS', 'MSL']: 0.0
# Diff of ['FSL', 'Mass Measurement Device']: 0.0
# Diff of ['PCRF', 'SLAMMD']: 0.0
# Diff of ['EMCS', 'Mass Measurement Device']: 0.0
# Diff of ['TVIS', 'WORF']: 0.0
# Diff of ['SLAMMD', 'CB']: 0.0
# Diff of ['LMM', 'EDR']: 0.0
# Diff of ['CBEF', 'Actiwatch']: 0.0
# Diff of ['Mass Measurement Device', 'CB']: 0.0002483854942871358
# Itemset not found: ['FPEF', 'MELFI']
# Diff of ['Solar', 'LMM']: 0.00024838549428713233
# Diff of ['MSG', 'EDR']: 0.0
# Diff of ['FPEF', 'MSG']: 0.0
# Diff of ['PCRF', 'Mass Measurement Device']: 0.0
# Diff of ['MSL', 'EPM']: 0.0
# Diff of ['EMCS', 'LMM']: 0.0
# Diff of ['Holter Monitor 2', 'EPM']: 0.0
# Diff of ['FSL', 'MSG']: 0.0
# Diff of ['EMCS', 'MSG']: 0.0
# Itemset not found: ['MWA', 'CEVIS']
# Diff of ['MELFI', 'EDR']: 0.0
# Diff of ['Portable Pulmonary Function System', 'CEVIS']: 0.0
